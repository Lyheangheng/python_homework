# %% [markdown]
# # แบบฝึกหัดบทที่ 6 นิพจน์ และตัวดำเนินการ

# %% [markdown]
# ![chap6_1.png](attachment:cfede8aa-daae-4c37-88dc-cc1a9662e131.png)<img src="./images/chap6_1.png" width=460px>

# %% [markdown]
# ## 5.1 จงแปลงนิพจน์ทางคณิตศาสตร์ให้เป็นโปรแกรม

# %%
#คำตอบ
r = 3
pi = 3.14
a = pi*(r**2)
print(a)
# Out:
# 28.26

# %% [markdown]
# ## 5.2 จงแปลงนิพจน์ทางคณิตศาสตร์ให้เป็นโปรแกรม

# %%
#คำตอบ
a=1
b=2
c=(a**2) + (b**2)
print(c**2)
# Out:
# 25

# %% [markdown]
# ## 5.3 จงแปลงนิพจน์ทางคณิตศาสตร์ให้เป็นโปรแกรม

# %%
#คำตอบ
a=1 
b=2
c=1
x = (((b ** 2) - (4*a*c)) ** (1/2)) / 2*a
print(x)
# Out:
# 0.0

# %% [markdown]
# ## 5.4 จงแปลงนิพจน์ทางคณิตศาสตร์ให้เป็นโปรแกรม

# %%
#คำตอบ
b=1
d=2
c=4
a = ((b*2)*d)/c
print(a)
# Out:
# 1.0

# %% [markdown]
# ## 5.5 จงแปลงนิพจน์ทางคณิตศาสตร์ให้เป็นโปรแกรม

# %%
# คำตอบ
b=2
a = (b ** 2) * (5+2)
print(a)
# Out:
# 28

# %% [markdown]
# ## แบบฝึกหัดเพิ่มเติม

# %% [markdown]
# - ดังนั้นเพื่อความปลอดภัย เราจึงนิยมเขียนเครื่องหมายยกกำลัง `**` ติดกับตัวเลข เพื่อให้เป็นที่รู้กันว่า ถ้าหากไม่มีวงเล็บ เราจะเริ่มทำจากเครื่องหมายยกกำลังก่อนเสมอ เช่น เราจะเขียนนิพจน์ $ 2 \times 5^3 $ ด้วยคำสั่ง `2 * 5**3` เป็นต้น

# %% [markdown]
# - นอกจากนี้เรายังสามารถคำนวณค่าราก (root) ได้โดยการใช้สูตร:
#
# $$ \sqrt[r]{a} = a^{1/r} $$
#
# - เช่น เราสามารถคำนวณค่า $ \sqrt[3]{8} $ (รากที่ 3 ของ 8) ได้โดยคำสั่ง `8**(1/3)`

# %%
8**(1/3)
# Out:
# 2.0

# %% [markdown]
# เรามาลองคำนวณค่าของนิพจน์ทางคณิตศาสตร์ต่อไปนี้กันครับ
#
# 1. $ 3 \times (4 + 1 - 2 \times 5) $

# %%
3*(4+1- 2*5)
# Out:
# -15

# %% [markdown]
# 2. $ \frac{1 + 2 + 3}{4 + 5 + 6} $   [**หมายเหตุ:** โปรดเลือกการใช้เครื่องหมายวงเล็บด้วยความระมัดระวัง]

# %%
(1+2+3) / (4+5+6)
# Out:
# 0.4

# %% [markdown]
# 3. $ 7 \times \frac{5 + 6}{7 + \frac{7}{8}} $

# %%
7 * (5 + 6)/(7 + 7/8)
# Out:
# 9.777777777777779

# %% [markdown]
# เรามาคำนวณค่าของนิพจน์ดังต่อไปนี้กันครับ
#
# 4. $ 3^{5 + 3/4} $

# %%
3 ** (5+3/4)

# %% [markdown]
# 5. $ \sqrt[2]{\left( 7 + 3 \times 4 \right)} $

# %%
(7+ 3*4) ** (1/2)
# Out:
# 4.358898943540674

# %% [markdown]
# 6. $ \frac{5 + 6^{2.5}}{\sqrt[2]{3.5}} + 3^2 $

# %%
(5+6**(2.5)) / 3.5**(1/2) + (3**2)

# %% [markdown]
# ตัวอย่าง ตู้ ATM
#
# ภายในตู้ ATM มีแบงค์สำหรับให้บริการสำหรับการถอน ประกอบไปด้วยแบงค์มูลค่า 1000, 500 และ 100 บาท
#
# ในการเบิกเงิน ผู้ใชังานเลือกกรอกจำนวนเงินที่ต้องการเบิกได้ เช่น
#
# กรอกเงินจำนวน 1900 บาท
# ตู้ ATM จะทำการพิจารณาจ่ายแบงค์ที่มีมูลค่าสูงสุดก่อน และค่อยพิจารณาจ่ายแบงค์มูลค่ารองลงมา
#
# input : 1900
#
# 1000 : 1
#
# 500 : 1
#
# 100 : 4

# %%
value = int(input("Enter your money : "))
print("1000 : {}".format(value//1000))
print("500 :{}".format(value%1000//500))
print("100:{}".format(value%1000%500//100))
# Out:
# Enter your money :  1900
# 1000 : 1
# 500 :1
# 100:4
